# %% [markdown]
# # Matematicas para la computación
#
# ### Taller acerca de emparejamientos y grafos bipartitos
#
# #### Jhon Edwin Sanz y Juan José Vera

# %% [markdown]
# ---
# ##### 1.
# El match de la figura 1, ¿es maximum?¿maximal?
# ![png](images/match-ej-1.png)

# %% [markdown]
# ---
# ##### 2.
# Iniciando con el match indicado y usando trayectorias de aumento encuentre un match maximum en el grafo de la figura 3.
# Cuando todos los vértices de un grafo están saturados por un match M, se dice que el match es perfecto.

# %% [markdown]
# ---
# ##### 3.
# Un problema de conteo. ¿Cuantos matchs perfectos hay en K 4 ? ¿ En K 6 ? Y en general, ¿En K 2n?
# ![png](images/match-ej-3.png)

# %% [markdown]
# ---
# ##### 4.
# ¿Es el grafo de la figura 7 bipartito?
# ![png](images/match-ej-4.png)

# %% [markdown]
# ---
# ##### 5.
# El problema del paseo del caballo:
# ¿Puede el caballo hacer un recorrido visitando cada casilla de un tablero de ajedrez una única vez y terminando en la casilla en la que empezó?
# ¿Como se puede plantear el problema con teoría de grafos?
# La figura 8 muestra la solución para un tablero de 8 × 8.9 ¿Cuál es la solución para un tablero de 5 × 5? Generalize su resultado.
# ![png](images/match-ej-5.png)

# %% [markdown]
# ---
# ##### 6.
# Un cuadrado latino es un arreglo n × n en el que cada fila y cada columna contienen los números de 1 a n en algún orden. Un rectángulo latino es un cuadrado latino incompleto.
# Figura 10 a) Un cuadrado latino. b) Un rectángulo latino.
# Demuestre que cualquier rectángulo latino siempre se puede extender hasta tener un cuadrado latino.
#
# ![png](images/match-ej-6.png)

# %% [markdown]
# ---
# ##### 7.
# Organice una baraja de cartas en 4 filas y 13 columnas de forma aleatoria. Demuestre que siempre es posible escoger una carta de cada columna de modo que tenga 13 cartas con todos los posibles valores A, 2, 3,. . . ,10, J, Q, K.

# %% [markdown]
# ---
# ##### 8.
# Otro problema combinatorio. ¿Cuántos matchs perfectos tiene la "escalera" con 2n nodos?
# ![png](images/match-ej-8.png)

# %% [markdown]
# ---
# ##### 9.
#
# H = { Juan , Pedro, Luis, Manuel , Carlos }
#
# M = { Anna, María, Luisa, Carol, Patricia }
#
# **Listas de preferencia mujeres**
# - a ← [J, L, P, M, C]
# - l ← [L, C, M, J, P ]
# - p ← [M, P, L, C, J]
# - m ← [P, L, J, C, M ]
# - c ← [J, L, P, M, C]
#
# **Listas de preferencia hombres**
# - J ← [c, a, m, l, p]
# - P ← [c, p, m, a, l]
# - L ← [p, a, l, m, c]
# - M ← [p, m, l, c, a]
# - C ← [a, l, c, m, p]
#
# ¿Cuál es el resultado si en el ejemplo anterior se aplica la versión feminista (las mujeres son las
# seleccionadas para elegir) del algoritmo de Gale-Shapley?
