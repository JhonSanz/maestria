# %% [markdown]
# # Matematicas para la computación
#
# ### Taller acerca de coloreado de grafos
#
# #### Jhon Edwin Sanz y Juan José Vera

# %% [markdown]
# ---
# ##### 1.
# ¿Puede dibujar el grafo de la figura 1 de modo que ningún par de aristas se intersecten?
# ![png](images/col-ej-1.png)
#
# ##### Desarrollo.
#
# - v = 6
# - a = 12
# - c = 23
#
# $$ v - a - c = 6 - 12 + 23 = 17 $$
#
# El grafo no cumple con la preciosa fórmula de Euler: v − a + c = 2, por lo tanto, no es planar y como no es planar no se puede dibujar de modo que ningún par de aristas se intersecten

# %% [markdown]
# ---
# ##### 2.
# Un Imperio está formado por varios países. Considere el problema de colorear un mapa de imperios de modo que todos los países que forman un imperio tengan el mismo color. Construya un mapa de n imperios que requiera n colores. Un imperio puede tener tantos países como se quiera.
#
# ##### Desarrollo.
#
# Tenemos 5 imperios, definidos con letras mayusculas, y que tienen la siguiente denominacion de paises
#
# - $ A = A_1 $
# - $ B = B_1, B_2 $
# - $ C = C_1, C_2, C_3 $
# - $ D = D_1, D_2, D_3, D_4 $
# - $ E = E_1, E_2, E_3, E_4, E_5 $
#
# ![png](images/col-ej-2.png)

# %% [markdown]
# ---
# ##### 3.
# Construya un ejemplo para mostrar que en un mismo grafo, si se cambia el orden de los vértices el algoritmo de coloreado secuencial puede producir resultados (cantidad de colores) diferentes.
#
# ##### Desarrollo.
#
# ![png](images/col-ej-3R-1.png)
# ![png](images/col-ej-3R-2R.png)

# %% [markdown]
# ---
# ##### 4.
# En el grafo completo $ K_n $, ¿Cual es la cantidad mínima de arcos que se pueden eliminar para que el grafo sea planar? Grafique para $ K_6 $ y $ K_7 $
#
# ##### Desarrollo
